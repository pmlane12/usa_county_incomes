# %%
import os
import pandas as pd
pd.set_option('precision', 2)

# %%
DATA_FOLDER = 'data'

# %% [markdown]
# # Load data

# %%
# https://www.bea.gov/news/2021/personal-income-county-and-metropolitan-area-2020
counties_df = pd.read_csv(
    os.path.join(DATA_FOLDER, 'county_income_2020.csv'),
    header=1,
)

# Force comma-delimited numbers to floats
# Add personal income to column name
for year in ['2018', '2019', '2020']:
    counties_df[year] = pd.to_numeric(counties_df[year].str.replace(',', ''), errors='coerce')
    counties_df.rename(columns={year: 'Personal income '+year}, inplace=True)

counties_df
# Out:
#              County          State  Personal income 2018  \
# 0     United States  United States               54098.0
# 1           Alabama        Alabama               42328.0
# 2           Autauga        Alabama               42931.0
# 3           Baldwin        Alabama               46905.0
# 4           Barbour        Alabama               34064.0
# ...             ...            ...                   ...
# 3161     Sweetwater        Wyoming               54941.0
# 3162          Teton        Wyoming              217958.0
# 3163          Uinta        Wyoming               40205.0
# 3164       Washakie        Wyoming               48717.0
# 3165         Weston        Wyoming               45047.0
#
#       Personal income 2019  Personal income 2020
# 0                  56047.0               59510.0
# 1                  43996.0               46479.0
# 2                  44368.0               46814.0
# 3                  48270.0               50953.0
# 4                  35572.0               37850.0
# ...                    ...                   ...
# 3161               55947.0               54000.0
# 3162              222893.0              220645.0
# 3163               41392.0               42854.0
# 3164               51138.0               54361.0
# 3165               46658.0               47599.0
#
# [3166 rows x 5 columns]

# %%
# https://www.bea.gov/news/2021/real-personal-consumption-expenditures-and-personal-income-state-2020
msa_rpp_df = pd.read_csv(os.path.join(DATA_FOLDER, 'msa_rpp_2020.csv'))

# Add personal income to column names
for col in msa_rpp_df.columns[1:]:
    msa_rpp_df.rename(columns={col: col+' RPP'}, inplace=True)

msa_rpp_df
# Out:
#           Metropolitan Statisical Area  All items RPP  Goods RPP  Housing RPP  \
# 0                        United States          100.0       99.7        100.4
# 1               Non-Metropolitan Areas           89.0       96.1         61.5
# 2                          Abilene, TX           94.4       97.0         80.0
# 3                            Akron, OH           93.0       93.7         78.8
# 4                           Albany, GA           84.6       95.0         49.6
# ..                                 ...            ...        ...          ...
# 381                         Yakima, WA           96.0      103.8         76.1
# 382                   York-Hanover, PA           97.2       98.5         87.6
# 383  Youngstown-Warren-Boardman, OH-PA           87.6       93.8         58.7
# 384                      Yuba City, CA           99.5      103.2         88.5
# 385                           Yuma, AZ           88.7       96.3         66.9
#
#      Utilities RPP  Other RPP
# 0             98.2      100.2
# 1             98.4       97.7
# 2            111.6       99.8
# 3             95.5       97.3
# 4            109.6       95.3
# ..             ...        ...
# 381           89.3      101.2
# 382           95.2       99.5
# 383           95.5       97.3
# 384           95.3      101.4
# 385          102.9       94.5
#
# [386 rows x 6 columns]

# %%
# https://www.census.gov/geographies/reference-files/time-series/demo/metro-micro/delineation-files.html
# March 2020
delineation_df = pd.read_csv(os.path.join(DATA_FOLDER, 'delineation_file.csv'))

delineation_df
# Out:
#       CBSA Code  Metropolitan Division Code  CSA Code      CBSA Title  \
# 0         10100                         NaN       NaN    Aberdeen, SD
# 1         10100                         NaN       NaN    Aberdeen, SD
# 2         10140                         NaN       NaN    Aberdeen, WA
# 3         10180                         NaN       NaN     Abilene, TX
# 4         10180                         NaN       NaN     Abilene, TX
# ...         ...                         ...       ...             ...
# 1911      49700                         NaN     472.0   Yuba City, CA
# 1912      49700                         NaN     472.0   Yuba City, CA
# 1913      49740                         NaN       NaN        Yuma, AZ
# 1914      49780                         NaN     198.0  Zanesville, OH
# 1915      49820                         NaN       NaN      Zapata, TX
#
#      Metropolitan/Micropolitan Statistical Area Metropolitan Division Title  \
# 0                 Micropolitan Statistical Area                         NaN
# 1                 Micropolitan Statistical Area                         NaN
# 2                 Micropolitan Statistical Area                         NaN
# 3                 Metropolitan Statistical Area                         NaN
# 4                 Metropolitan Statistical Area                         NaN
# ...                                         ...                         ...
# 1911              Metropolitan Statistical Area                         NaN
# 1912              Metropolitan Statistical Area                         NaN
# 1913              Metropolitan Statistical Area                         NaN
# 1914              Micropolitan Statistical Area                         NaN
# 1915              Micropolitan Statistical Area                         NaN
#
#                            CSA Title County/County Equivalent    State Name  \
# 0                                NaN             Brown County  South Dakota
# 1                                NaN           Edmunds County  South Dakota
# 2                                NaN      Grays Harbor County    Washington
# 3                                NaN          Callahan County         Texas
# 4                                NaN             Jones County         Texas
# ...                              ...                      ...           ...
# 1911        Sacramento-Roseville, CA            Sutter County    California
# 1912        Sacramento-Roseville, CA              Yuba County    California
# 1913                             NaN              Yuma County       Arizona
# 1914  Columbus-Marion-Zanesville, OH         Muskingum County          Ohio
# 1915                             NaN            Zapata County         Texas
#
#       FIPS State Code  FIPS County Code Central/Outlying County
# 0                  46                13                 Central
# 1                  46                45                Outlying
# 2                  53                27                 Central
# 3                  48                59                Outlying
# 4                  48               253                Outlying
# ...               ...               ...                     ...
# 1911                6               101                 Central
# 1912                6               115                 Central
# 1913                4                27                 Central
# 1914               39               119                 Central
# 1915               48               505                 Central
#
# [1916 rows x 12 columns]

# %% [markdown]
# # Merge

# %%
# Only care about metropolitan areas
msa_only = (
    delineation_df['Metropolitan/Micropolitan Statistical Area'] == 'Metropolitan Statistical Area'
)

# Keep counties/states and CBSAs
county_to_cbsa_df = delineation_df[msa_only][['County/County Equivalent', 'State Name', 'CBSA Title']]

# Remove County from names
county_to_cbsa_df['County/County Equivalent'] = county_to_cbsa_df['County/County Equivalent'].str.replace(' County', '')
county_to_cbsa_df['County/County Equivalent'] = county_to_cbsa_df['County/County Equivalent'].str.replace(' Municipio', '')

county_to_cbsa_df.head()
# Out:
#   County/County Equivalent   State Name             CBSA Title
# 3                 Callahan        Texas            Abilene, TX
# 4                    Jones        Texas            Abilene, TX
# 5                   Taylor        Texas            Abilene, TX
# 8                   Aguada  Puerto Rico  Aguadilla-Isabela, PR
# 9                Aguadilla  Puerto Rico  Aguadilla-Isabela, PR

# %%
# Merge CBSA for each county
merge_df = pd.merge(
    counties_df,
    county_to_cbsa_df,
    how='left',
    left_on=['County', 'State'],
    right_on=['County/County Equivalent', 'State Name']
)

# Merge RPP for each CBSA
merge_df = pd.merge(
    merge_df,
    msa_rpp_df,
    how='left',
    left_on='CBSA Title',
    right_on='Metropolitan Statisical Area',
)

merge_df
# Out:
#              County          State  Personal income 2018  \
# 0     United States  United States               54098.0
# 1           Alabama        Alabama               42328.0
# 2           Autauga        Alabama               42931.0
# 3           Baldwin        Alabama               46905.0
# 4           Barbour        Alabama               34064.0
# ...             ...            ...                   ...
# 3161     Sweetwater        Wyoming               54941.0
# 3162          Teton        Wyoming              217958.0
# 3163          Uinta        Wyoming               40205.0
# 3164       Washakie        Wyoming               48717.0
# 3165         Weston        Wyoming               45047.0
#
#       Personal income 2019  Personal income 2020 County/County Equivalent  \
# 0                  56047.0               59510.0                      NaN
# 1                  43996.0               46479.0                      NaN
# 2                  44368.0               46814.0                  Autauga
# 3                  48270.0               50953.0                  Baldwin
# 4                  35572.0               37850.0                      NaN
# ...                    ...                   ...                      ...
# 3161               55947.0               54000.0                      NaN
# 3162              222893.0              220645.0                      NaN
# 3163               41392.0               42854.0                      NaN
# 3164               51138.0               54361.0                      NaN
# 3165               46658.0               47599.0                      NaN
#
#      State Name                 CBSA Title Metropolitan Statisical Area  \
# 0           NaN                        NaN                          NaN
# 1           NaN                        NaN                          NaN
# 2       Alabama             Montgomery, AL               Montgomery, AL
# 3       Alabama  Daphne-Fairhope-Foley, AL    Daphne-Fairhope-Foley, AL
# 4           NaN                        NaN                          NaN
# ...         ...                        ...                          ...
# 3161        NaN                        NaN                          NaN
# 3162        NaN                        NaN                          NaN
# 3163        NaN                        NaN                          NaN
# 3164        NaN                        NaN                          NaN
# 3165        NaN                        NaN                          NaN
#
#       All items RPP  Goods RPP  Housing RPP  Utilities RPP  Other RPP
# 0               NaN        NaN          NaN            NaN        NaN
# 1               NaN        NaN          NaN            NaN        NaN
# 2              90.6       95.1         64.9          118.5       97.8
# 3              96.9       95.1         95.5          118.5       97.8
# 4               NaN        NaN          NaN            NaN        NaN
# ...             ...        ...          ...            ...        ...
# 3161            NaN        NaN          NaN            NaN        NaN
# 3162            NaN        NaN          NaN            NaN        NaN
# 3163            NaN        NaN          NaN            NaN        NaN
# 3164            NaN        NaN          NaN            NaN        NaN
# 3165            NaN        NaN          NaN            NaN        NaN
#
# [3166 rows x 14 columns]

# %%
# Can only calculate for counties in a CBSA
msa_merge_df = merge_df[~merge_df['Metropolitan Statisical Area'].isna()].copy()

# Adjusting for All items RPP
msa_merge_df['2020 personal income (RPP All items)'] = msa_merge_df['Personal income 2020']*(100/msa_merge_df['All items RPP'])
msa_merge_df.sort_values(by='2020 personal income (RPP All items)', ascending=False, inplace=True)
msa_merge_df.reset_index(drop=True, inplace=True)

msa_merge_df[[
    'County',
    'Metropolitan Statisical Area',
    '2020 personal income (RPP All items)',
    'Personal income 2020',
    'All items RPP'
]].head(20)
# Out:
#            County                    Metropolitan Statisical Area  \
# 0        New York           New York-Newark-Jersey City, NY-NJ-PA
# 1           Union                            Sioux City, IA-NE-SD
# 2           Marin              San Francisco-Oakland-Berkeley, CA
# 3   San Francisco              San Francisco-Oakland-Berkeley, CA
# 4         Midland                                     Midland, TX
# 5       San Mateo              San Francisco-Oakland-Berkeley, CA
# 6       Fairfield                 Bridgeport-Stamford-Norwalk, CT
# 7       Goochland                                    Richmond, VA
# 8     Santa Clara              San Jose-Sunnyvale-Santa Clara, CA
# 9         Collier                         Naples-Marco Island, FL
# 10         Benton              Fayetteville-Springdale-Rogers, AR
# 11    Westchester           New York-Newark-Jersey City, NY-NJ-PA
# 12       Somerset           New York-Newark-Jersey City, NY-NJ-PA
# 13     Williamson  Nashville-Davidson--Murfreesboro--Franklin, TN
# 14         Fulton            Atlanta-Sandy Springs-Alpharetta, GA
# 15         Martin                              Port St. Lucie, FL
# 16        Ozaukee                          Milwaukee-Waukesha, WI
# 17      Arlington    Washington-Arlington-Alexandria, DC-VA-MD-WV
# 18        Chester     Philadelphia-Camden-Wilmington, PA-NJ-DE-MD
# 19        Norfolk                  Boston-Cambridge-Newton, MA-NH
#
#     2020 personal income (RPP All items)  Personal income 2020  All items RPP
# 0                              165558.44              191220.0          115.5
# 1                              136666.67              123000.0           90.0
# 2                              123999.15              145575.0          117.4
# 3                              123354.34              144818.0          117.4
# 4                              121294.06              126631.0          104.4
# 5                              120818.57              141841.0          117.4
# 6                              113867.42              120244.0          105.6
# 7                              110711.74              105619.0           95.4
# 8                              110313.11              123661.0          112.1
# 9                              102938.55              103865.0          100.9
# 10                             101060.02               94289.0           93.3
# 11                              99901.30              115386.0          115.5
# 12                              97683.98              112825.0          115.5
# 13                              97678.35               94748.0           97.0
# 14                              97436.86               95683.0           98.2
# 15                              92901.04               89185.0           96.0
# 16                              91131.39               87395.0           95.9
# 17                              90424.22              100823.0          111.5
# 18                              89860.22               91927.0          102.3
# 19                              88946.46               98019.0          110.2
